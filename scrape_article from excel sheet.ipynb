# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt
import requests

# %%
df= pd.read_excel("/content/Input (1) (1).xlsx", index_col=0)

# %%
df
# Out:
#                                                       URL
# URL_ID
# 37      https://insights.blackcoffer.com/ai-in-healthc...
# 38      https://insights.blackcoffer.com/what-if-the-c...
# 39      https://insights.blackcoffer.com/what-jobs-wil...
# 40      https://insights.blackcoffer.com/will-machine-...
# 41      https://insights.blackcoffer.com/will-ai-repla...
# ...                                                   ...
# 146     https://insights.blackcoffer.com/blockchain-fo...
# 147     https://insights.blackcoffer.com/the-future-of...
# 148     https://insights.blackcoffer.com/big-data-anal...
# 149     https://insights.blackcoffer.com/business-anal...
# 150     https://insights.blackcoffer.com/challenges-an...
#
# [114 rows x 1 columns]

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import urllib.error

for i in range(0, len(df["URL"])):
    try:
        html = urlopen(df["URL"].iloc[i])
        bs = BeautifulSoup(html, "html.parser")
        titles = bs.find_all(['h1'])
        print('List all the header tags :', *titles, sep='\n\n')
    except urllib.error.HTTPError as e:
        print(f"error accessing URL: {df['URL'].iloc[i]} - {e}")
# Out:
# List all the header tags :
#
# <h1 class="tdb-title-text">AI in healthcare to Improve Patient Outcomes</h1>
# List all the header tags :
#
# <h1 class="entry-title">What if the Creation is Taking Over the Creator?</h1>
# List all the header tags :
#
# <h1 class="entry-title">What Jobs Will Robots Take From Humans in The Future?</h1>
# List all the header tags :
#
# <h1 class="entry-title">Will Machine Replace The Human in the Future of Work?</h1>
# List all the header tags :
#
# <h1 class="entry-title">Will AI Replace Us or Work With Us?</h1>
# List all the header tags :
#
# <h1 class="entry-title">Will machine replace the human in the future of work?</h1>
# List all the header tags :
#
# <h1 class="entry-title">How humans and machines are evolving to work together?</h1>
# error accessing URL: https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future/ - HTTP Error 404: Not Found
# List all the header tags :
#
# ...

# %%
for i in range(0,len(df["URL"])):
  response = requests.get(df["URL"].iloc[0])  # Replace with the URL of the website
  html_content = response.content

  # Create a BeautifulSoup object
  soup = BeautifulSoup(html_content, 'html.parser')

  div_element = soup.find('div', class_='td_block_wrap tdb_single_content tdi_130 td-pb-border-top td_block_template_1 td-post-content tagdiv-type')  # Replace 'your-class-name' with the actual class name

  # Find all <p> tags within the specific <div> element and extract the text
  p_tags = div_element.find_all('p')

  file_name = f'article_{i}.txt'
  file = open(file_name, 'w')

    # Write the content of each <p> tag to the file
  for p_tag in p_tags:
      file.write(p_tag.text.strip() + '\n')

    # Close the file
  file.close()
